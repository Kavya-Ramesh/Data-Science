# %%
# Importing the necessary packages
import pandas as pd
import numpy as np
from tensorflow import keras
#import transflow.keras
from sklearn.preprocessing import StandardScaler

# %%
# load pima indians dataset
dataset = np.loadtxt("C:\\Data Science\\EnsembleTechniques\\pima-indians-diabetes.data.csv", delimiter=",")

# %%
X = dataset[:,0:8]
y = dataset[:,8]

# %%
# Standardization
a = StandardScaler()
a.fit(X)
X_standardized = a.transform(X)

# %%
pd.DataFrame(X_standardized).describe()
# Out:
#                   0             1             2             3             4  \
# count  7.680000e+02  7.680000e+02  7.680000e+02  7.680000e+02  7.680000e+02
# mean  -7.748432e-17  3.614007e-18 -1.327244e-17  7.762888e-17 -5.493291e-17
# std    1.000652e+00  1.000652e+00  1.000652e+00  1.000652e+00  1.000652e+00
# min   -1.141852e+00 -3.783654e+00 -3.572597e+00 -1.288212e+00 -6.928906e-01
# 25%   -8.448851e-01 -6.852363e-01 -3.673367e-01 -1.288212e+00 -6.928906e-01
# 50%   -2.509521e-01 -1.218877e-01  1.496408e-01  1.545332e-01 -4.280622e-01
# 75%    6.399473e-01  6.057709e-01  5.632228e-01  7.190857e-01  4.120079e-01
# max    3.906578e+00  2.444478e+00  2.734528e+00  4.921866e+00  6.652839e+00
#
#                   5             6             7
# count  7.680000e+02  7.680000e+02  7.680000e+02
# mean   2.972738e-15  1.924387e-15  2.192980e-16
# std    1.000652e+00  1.000652e+00  1.000652e+00
# min   -4.060474e+00 -1.189553e+00 -1.041549e+00
# 25%   -5.955785e-01 -6.889685e-01 -7.862862e-01
# 50%    9.419788e-04 -3.001282e-01 -3.608474e-01
# 75%    5.847705e-01  4.662269e-01  6.602056e-01
# max    4.455807e+00  5.883565e+00  4.063716e+00

# %% [markdown]
# #### Tuning of Hyperparameters :- Batch Size and Epochs

# %%
# Importing the necessary packages
from sklearn.model_selection import GridSearchCV, KFold
from tensorflow.keras.models import Sequential
from keras.layers import Dense
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.optimizers import Adam

# %%
# create model
def create_model():
    model = Sequential()
    model.add(Dense(12, input_dim=8,  kernel_initializer='uniform', activation='relu'))
    model.add(Dense(8,  kernel_initializer='uniform', activation='relu'))
    model.add(Dense(1, kernel_initializer='uniform', activation='sigmoid'))
    
    adam=Adam(lr=0.01)
    model.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])
    return model

# %%
# Create the model
model = KerasClassifier(build_fn = create_model,verbose = 0)
# Define the grid search parameters
batch_size = [10,20,40]
epochs = [10,50,100]
# Make a dictionary of the grid search parameters
param_grid = dict(batch_size = batch_size,epochs = epochs)
# Build and fit the GridSearchCV
grid = GridSearchCV(estimator = model,param_grid = param_grid,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] batch_size=10, epochs=10 ........................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# C:\Users\Kavya Ramesh\anaconda3\lib\site-packages\tensorflow\python\keras\optimizer_v2\optimizer_v2.py:374: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# [CV] ............ batch_size=10, epochs=10, score=0.727, total=   2.5s
# [CV] batch_size=10, epochs=10 ........................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.4s remaining:    0.0s
# [CV] ............ batch_size=10, epochs=10, score=0.727, total=   2.2s
# [CV] batch_size=10, epochs=10 ........................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    4.6s remaining:    0.0s
# [CV] ............ batch_size=10, epochs=10, score=0.792, total=   2.0s
# [CV] batch_size=10, epochs=10 ........................................
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    6.7s remaining:    0.0s
# [CV] ............ batch_size=10, epochs=10, score=0.830, total=   2.5s
# [CV] batch_size=10, epochs=10 ........................................
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    9.2s remaining:    0.0s
# [CV] ............ batch_size=10, epochs=10, score=0.752, total=   2.1s
# [CV] batch_size=10, epochs=50 ........................................
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   11.3s remaining:    0.0s
# [CV] ............ batch_size=10, epochs=50, score=0.734, total=   6.0s
# [CV] batch_size=10, epochs=50 ........................................
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:   17.4s remaining:    0.0s
# [CV] ............ batch_size=10, epochs=50, score=0.688, total=   5.3s
# [CV] batch_size=10, epochs=50 ........................................
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:   22.7s remaining:    0.0s
# [CV] ............ batch_size=10, epochs=50, score=0.792, total=   5.6s
# [CV] batch_size=10, epochs=50 ........................................
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:   28.3s remaining:    0.0s
# [CV] ............ batch_size=10, epochs=50, score=0.843, total=   5.3s
# [CV] batch_size=10, epochs=50 ........................................
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:   33.5s remaining:    0.0s
# [CV] ............ batch_size=10, epochs=50, score=0.765, total=   5.2s
# [CV] batch_size=10, epochs=100 .......................................
# [CV] ........... batch_size=10, epochs=100, score=0.727, total=   9.9s
# [CV] batch_size=10, epochs=100 .......................................
# [CV] ........... batch_size=10, epochs=100, score=0.688, total=  10.3s
# [CV] batch_size=10, epochs=100 .......................................
# [CV] ........... batch_size=10, epochs=100, score=0.727, total=  10.1s
# [CV] batch_size=10, epochs=100 .......................................
# [CV] ........... batch_size=10, epochs=100, score=0.804, total=  10.4s
# [CV] batch_size=10, epochs=100 .......................................
# [CV] ........... batch_size=10, epochs=100, score=0.784, total=  10.2s
# [CV] batch_size=20, epochs=10 ........................................
# [CV] ............ batch_size=20, epochs=10, score=0.753, total=   1.7s
# [CV] batch_size=20, epochs=10 ........................................
# [CV] ............ batch_size=20, epochs=10, score=0.701, total=   1.6s
# [CV] batch_size=20, epochs=10 ........................................
# [CV] ............ batch_size=20, epochs=10, score=0.753, total=   1.6s
# [CV] batch_size=20, epochs=10 ........................................
# [CV] ............ batch_size=20, epochs=10, score=0.843, total=   2.1s
# [CV] batch_size=20, epochs=10 ........................................
# [CV] ............ batch_size=20, epochs=10, score=0.758, total=   1.6s
# [CV] batch_size=20, epochs=50 ........................................
# [CV] ............ batch_size=20, epochs=50, score=0.727, total=   3.5s
# [CV] batch_size=20, epochs=50 ........................................
# [CV] ............ batch_size=20, epochs=50, score=0.734, total=   3.9s
# [CV] batch_size=20, epochs=50 ........................................
# [CV] ............ batch_size=20, epochs=50, score=0.740, total=   3.9s
# [CV] batch_size=20, epochs=50 ........................................
# [CV] ............ batch_size=20, epochs=50, score=0.810, total=   3.3s
# [CV] batch_size=20, epochs=50 ........................................
# [CV] ............ batch_size=20, epochs=50, score=0.758, total=   3.2s
# [CV] batch_size=20, epochs=100 .......................................
# [CV] ........... batch_size=20, epochs=100, score=0.747, total=   5.5s
# [CV] batch_size=20, epochs=100 .......................................
# [CV] ........... batch_size=20, epochs=100, score=0.708, total=   5.3s
# [CV] batch_size=20, epochs=100 .......................................
# [CV] ........... batch_size=20, epochs=100, score=0.766, total=   5.3s
# [CV] batch_size=20, epochs=100 .......................................
# [CV] ........... batch_size=20, epochs=100, score=0.791, total=   5.3s
# [CV] batch_size=20, epochs=100 .......................................
# [CV] ........... batch_size=20, epochs=100, score=0.752, total=   5.7s
# [CV] batch_size=40, epochs=10 ........................................
# [CV] ............ batch_size=40, epochs=10, score=0.727, total=   1.3s
# [CV] batch_size=40, epochs=10 ........................................
# [CV] ............ batch_size=40, epochs=10, score=0.721, total=   1.3s
# [CV] batch_size=40, epochs=10 ........................................
# [CV] ............ batch_size=40, epochs=10, score=0.773, total=   1.3s
# [CV] batch_size=40, epochs=10 ........................................
# [CV] ............ batch_size=40, epochs=10, score=0.843, total=   1.6s
# [CV] batch_size=40, epochs=10 ........................................
# [CV] ............ batch_size=40, epochs=10, score=0.752, total=   1.3s
# [CV] batch_size=40, epochs=50 ........................................
# [CV] ............ batch_size=40, epochs=50, score=0.747, total=   2.2s
# [CV] batch_size=40, epochs=50 ........................................
# [CV] ............ batch_size=40, epochs=50, score=0.708, total=   2.5s
# [CV] batch_size=40, epochs=50 ........................................
# [CV] ............ batch_size=40, epochs=50, score=0.740, total=   2.2s
# [CV] batch_size=40, epochs=50 ........................................
# [CV] ............ batch_size=40, epochs=50, score=0.791, total=   2.3s
# [CV] batch_size=40, epochs=50 ........................................
# [CV] ............ batch_size=40, epochs=50, score=0.745, total=   2.2s
# [CV] batch_size=40, epochs=100 .......................................
# [CV] ........... batch_size=40, epochs=100, score=0.747, total=   3.6s
# [CV] batch_size=40, epochs=100 .......................................
# [CV] ........... batch_size=40, epochs=100, score=0.701, total=   3.4s
# [CV] batch_size=40, epochs=100 .......................................
# [CV] ........... batch_size=40, epochs=100, score=0.786, total=   3.4s
# [CV] batch_size=40, epochs=100 .......................................
# [CV] ........... batch_size=40, epochs=100, score=0.784, total=   3.3s
# [CV] batch_size=40, epochs=100 .......................................
# [CV] ........... batch_size=40, epochs=100, score=0.765, total=   3.7s
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed:  3.0min finished

# %%
# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : 0.7656905293464661, using {'batch_size': 10, 'epochs': 10}
# 0.7656905293464661,0.03999180460616399 with: {'batch_size': 10, 'epochs': 10}
# 0.7644257783889771,0.05234649115720449 with: {'batch_size': 10, 'epochs': 50}
# 0.7462185025215149,0.04207605868368702 with: {'batch_size': 10, 'epochs': 100}
# 0.7618198752403259,0.04568511472354803 with: {'batch_size': 20, 'epochs': 10}
# 0.7539852499961853,0.03005789115182522 with: {'batch_size': 20, 'epochs': 50}
# 0.7526525855064392,0.0271726252715986 with: {'batch_size': 20, 'epochs': 100}
# 0.7631101012229919,0.04405622514856611 with: {'batch_size': 40, 'epochs': 10}
# 0.7461506009101868,0.026478468129156822 with: {'batch_size': 40, 'epochs': 50}
# 0.7565571784973144,0.031101699553156233 with: {'batch_size': 40, 'epochs': 100}

# %% [markdown]
# #### Tuning of Hyperparameters:- Learning rate and Drop out rate

# %%
from keras.layers import Dropout

# Defining the model

def create_model(learning_rate,dropout_rate):
    model = Sequential()
    model.add(Dense(8,input_dim = 8,kernel_initializer = 'normal',activation = 'relu'))
    model.add(Dropout(dropout_rate))
    model.add(Dense(4,input_dim = 8,kernel_initializer = 'normal',activation = 'relu'))
    model.add(Dropout(dropout_rate))
    model.add(Dense(1,activation = 'sigmoid'))
    
    adam = Adam(lr = learning_rate)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# Create the model

model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)

# Define the grid search parameters

learning_rate = [0.001,0.01,0.1]
dropout_rate = [0.0,0.1,0.2]

# Make a dictionary of the grid search parameters

param_grids = dict(learning_rate = learning_rate,dropout_rate = dropout_rate)

# Build and fit the GridSearchCV

grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] dropout_rate=0.0, learning_rate=0.001 ...........................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  dropout_rate=0.0, learning_rate=0.001, score=0.649, total=   1.4s
# [CV] dropout_rate=0.0, learning_rate=0.001 ...........................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.3s remaining:    0.0s
# [CV]  dropout_rate=0.0, learning_rate=0.001, score=0.688, total=   1.4s
# [CV] dropout_rate=0.0, learning_rate=0.001 ...........................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    2.7s remaining:    0.0s
# [CV]  dropout_rate=0.0, learning_rate=0.001, score=0.773, total=   1.6s
# [CV] dropout_rate=0.0, learning_rate=0.001 ...........................
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    4.3s remaining:    0.0s
# [CV]  dropout_rate=0.0, learning_rate=0.001, score=0.817, total=   1.4s
# [CV] dropout_rate=0.0, learning_rate=0.001 ...........................
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    5.7s remaining:    0.0s
# [CV]  dropout_rate=0.0, learning_rate=0.001, score=0.771, total=   1.4s
# [CV] dropout_rate=0.0, learning_rate=0.01 ............................
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    7.0s remaining:    0.0s
# [CV]  dropout_rate=0.0, learning_rate=0.01, score=0.753, total=   1.4s
# [CV] dropout_rate=0.0, learning_rate=0.01 ............................
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    8.4s remaining:    0.0s
# [CV]  dropout_rate=0.0, learning_rate=0.01, score=0.701, total=   1.6s
# [CV] dropout_rate=0.0, learning_rate=0.01 ............................
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:   10.1s remaining:    0.0s
# [CV]  dropout_rate=0.0, learning_rate=0.01, score=0.766, total=   1.4s
# [CV] dropout_rate=0.0, learning_rate=0.01 ............................
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:   11.4s remaining:    0.0s
# [CV]  dropout_rate=0.0, learning_rate=0.01, score=0.791, total=   1.3s
# [CV] dropout_rate=0.0, learning_rate=0.01 ............................
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:   12.8s remaining:    0.0s
# [CV]  dropout_rate=0.0, learning_rate=0.01, score=0.778, total=   1.4s
# [CV] dropout_rate=0.0, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.0, learning_rate=0.1, score=0.753, total=   1.6s
# [CV] dropout_rate=0.0, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.0, learning_rate=0.1, score=0.753, total=   1.4s
# [CV] dropout_rate=0.0, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.0, learning_rate=0.1, score=0.773, total=   1.3s
# [CV] dropout_rate=0.0, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.0, learning_rate=0.1, score=0.810, total=   1.4s
# [CV] dropout_rate=0.0, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.0, learning_rate=0.1, score=0.725, total=   1.7s
# [CV] dropout_rate=0.1, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.1, learning_rate=0.001, score=0.649, total=   1.5s
# [CV] dropout_rate=0.1, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.1, learning_rate=0.001, score=0.584, total=   1.5s
# [CV] dropout_rate=0.1, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.1, learning_rate=0.001, score=0.753, total=   1.7s
# [CV] dropout_rate=0.1, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.1, learning_rate=0.001, score=0.817, total=   1.4s
# [CV] dropout_rate=0.1, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.1, learning_rate=0.001, score=0.765, total=   1.5s
# [CV] dropout_rate=0.1, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.1, learning_rate=0.01, score=0.753, total=   1.5s
# [CV] dropout_rate=0.1, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.1, learning_rate=0.01, score=0.714, total=   1.8s
# [CV] dropout_rate=0.1, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.1, learning_rate=0.01, score=0.766, total=   1.4s
# [CV] dropout_rate=0.1, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.1, learning_rate=0.01, score=0.824, total=   1.5s
# [CV] dropout_rate=0.1, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.1, learning_rate=0.01, score=0.771, total=   1.7s
# [CV] dropout_rate=0.1, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.1, learning_rate=0.1, score=0.740, total=   1.5s
# [CV] dropout_rate=0.1, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.1, learning_rate=0.1, score=0.688, total=   1.5s
# [CV] dropout_rate=0.1, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.1, learning_rate=0.1, score=0.766, total=   1.4s
# [CV] dropout_rate=0.1, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.1, learning_rate=0.1, score=0.725, total=   1.8s
# [CV] dropout_rate=0.1, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.1, learning_rate=0.1, score=0.725, total=   1.4s
# [CV] dropout_rate=0.2, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.2, learning_rate=0.001, score=0.766, total=   1.5s
# [CV] dropout_rate=0.2, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.2, learning_rate=0.001, score=0.675, total=   1.5s
# [CV] dropout_rate=0.2, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.2, learning_rate=0.001, score=0.740, total=   1.7s
# [CV] dropout_rate=0.2, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.2, learning_rate=0.001, score=0.804, total=   1.5s
# [CV] dropout_rate=0.2, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.2, learning_rate=0.001, score=0.725, total=   1.5s
# [CV] dropout_rate=0.2, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.2, learning_rate=0.01, score=0.766, total=   1.7s
# [CV] dropout_rate=0.2, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.2, learning_rate=0.01, score=0.688, total=   1.4s
# [CV] dropout_rate=0.2, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.2, learning_rate=0.01, score=0.766, total=   1.5s
# [CV] dropout_rate=0.2, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.2, learning_rate=0.01, score=0.830, total=   1.5s
# [CV] dropout_rate=0.2, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.2, learning_rate=0.01, score=0.765, total=   1.8s
# [CV] dropout_rate=0.2, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.2, learning_rate=0.1, score=0.740, total=   1.4s
# [CV] dropout_rate=0.2, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.2, learning_rate=0.1, score=0.584, total=   1.5s
# [CV] dropout_rate=0.2, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.2, learning_rate=0.1, score=0.753, total=   1.5s
# [CV] dropout_rate=0.2, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.2, learning_rate=0.1, score=0.706, total=   1.8s
# [CV] dropout_rate=0.2, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.2, learning_rate=0.1, score=0.647, total=   1.4s
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed:  1.1min finished

# %%
# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : 0.7657074928283691, using {'dropout_rate': 0.1, 'learning_rate': 0.01}
# 0.7397249817848206,0.061422682180917704 with: {'dropout_rate': 0.0, 'learning_rate': 0.001}
# 0.7578813314437867,0.030905069044604362 with: {'dropout_rate': 0.0, 'learning_rate': 0.01}
# 0.7630336880683899,0.028085824156242802 with: {'dropout_rate': 0.0, 'learning_rate': 0.1}
# 0.713742458820343,0.0844871413799672 with: {'dropout_rate': 0.1, 'learning_rate': 0.001}
# 0.7657074928283691,0.03513900910859226 with: {'dropout_rate': 0.1, 'learning_rate': 0.01}
# 0.7291571259498596,0.02527127126643817 with: {'dropout_rate': 0.1, 'learning_rate': 0.1}
# 0.7422459959983826,0.042760855479283315 with: {'dropout_rate': 0.2, 'learning_rate': 0.001}
# 0.763110089302063,0.044944121325995526 with: {'dropout_rate': 0.2, 'learning_rate': 0.01}
# 0.6861726522445679,0.06276498530765166 with: {'dropout_rate': 0.2, 'learning_rate': 0.1}

# %% [markdown]
# #### Tuning of Hyperparameters:- Activation Function and Kernel Initializer

# %%
# Defining the model

def create_model(activation_function,init):
    model = Sequential()
    model.add(Dense(8,input_dim = 8,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(0.1))
    model.add(Dense(4,input_dim = 8,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(0.1))
    model.add(Dense(1,activation = 'sigmoid'))
    
    adam = Adam(lr = 0.001)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# Create the model

model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)

# Define the grid search parameters
activation_function = ['softmax','relu','tanh','linear']
init = ['uniform','normal','zero']

# Make a dictionary of the grid search parameters
param_grids = dict(activation_function = activation_function,init = init)

# Build and fit the GridSearchCV

grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV] activation_function=softmax, init=uniform .......................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  activation_function=softmax, init=uniform, score=0.649, total=   1.8s
# [CV] activation_function=softmax, init=uniform .......................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.7s remaining:    0.0s
# [CV]  activation_function=softmax, init=uniform, score=0.584, total=   1.5s
# [CV] activation_function=softmax, init=uniform .......................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.2s remaining:    0.0s
# [CV]  activation_function=softmax, init=uniform, score=0.630, total=   1.5s
# [CV] activation_function=softmax, init=uniform .......................
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    4.7s remaining:    0.0s
# [CV]  activation_function=softmax, init=uniform, score=0.261, total=   1.5s
# [CV] activation_function=softmax, init=uniform .......................
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    6.2s remaining:    0.0s
# [CV]  activation_function=softmax, init=uniform, score=0.647, total=   1.8s
# [CV] activation_function=softmax, init=normal ........................
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    8.1s remaining:    0.0s
# [CV]  activation_function=softmax, init=normal, score=0.649, total=   1.5s
# [CV] activation_function=softmax, init=normal ........................
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    9.6s remaining:    0.0s
# [CV]  activation_function=softmax, init=normal, score=0.584, total=   1.5s
# [CV] activation_function=softmax, init=normal ........................
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:   11.1s remaining:    0.0s
# [CV]  activation_function=softmax, init=normal, score=0.630, total=   1.5s
# [CV] activation_function=softmax, init=normal ........................
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:   12.6s remaining:    0.0s
# [CV]  activation_function=softmax, init=normal, score=0.745, total=   1.8s
# [CV] activation_function=softmax, init=normal ........................
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:   14.4s remaining:    0.0s
# [CV]  activation_function=softmax, init=normal, score=0.647, total=   1.5s
# [CV] activation_function=softmax, init=zero ..........................
# [CV]  activation_function=softmax, init=zero, score=0.351, total=   1.5s
# [CV] activation_function=softmax, init=zero ..........................
# [CV]  activation_function=softmax, init=zero, score=0.584, total=   1.8s
# [CV] activation_function=softmax, init=zero ..........................
# [CV]  activation_function=softmax, init=zero, score=0.370, total=   1.5s
# [CV] activation_function=softmax, init=zero ..........................
# [CV]  activation_function=softmax, init=zero, score=0.255, total=   1.5s
# [CV] activation_function=softmax, init=zero ..........................
# [CV]  activation_function=softmax, init=zero, score=0.353, total=   1.5s
# [CV] activation_function=relu, init=uniform ..........................
# [CV]  activation_function=relu, init=uniform, score=0.760, total=   1.7s
# [CV] activation_function=relu, init=uniform ..........................
# [CV]  activation_function=relu, init=uniform, score=0.708, total=   1.5s
# [CV] activation_function=relu, init=uniform ..........................
# [CV]  activation_function=relu, init=uniform, score=0.630, total=   1.6s
# [CV] activation_function=relu, init=uniform ..........................
# [CV]  activation_function=relu, init=uniform, score=0.804, total=   1.7s
# [CV] activation_function=relu, init=uniform ..........................
# [CV]  activation_function=relu, init=uniform, score=0.719, total=   1.4s
# [CV] activation_function=relu, init=normal ...........................
# [CV]  activation_function=relu, init=normal, score=0.779, total=   1.5s
# [CV] activation_function=relu, init=normal ...........................
# [CV]  activation_function=relu, init=normal, score=0.584, total=   1.5s
# [CV] activation_function=relu, init=normal ...........................
# [CV]  activation_function=relu, init=normal, score=0.630, total=   1.7s
# [CV] activation_function=relu, init=normal ...........................
# [CV]  activation_function=relu, init=normal, score=0.804, total=   1.5s
# [CV] activation_function=relu, init=normal ...........................
# [CV]  activation_function=relu, init=normal, score=0.647, total=   1.6s
# [CV] activation_function=relu, init=zero .............................
# [CV] . activation_function=relu, init=zero, score=0.649, total=   1.9s
# [CV] activation_function=relu, init=zero .............................
# [CV] . activation_function=relu, init=zero, score=0.584, total=   1.6s
# [CV] activation_function=relu, init=zero .............................
# [CV] . activation_function=relu, init=zero, score=0.630, total=   1.5s
# [CV] activation_function=relu, init=zero .............................
# [CV] . activation_function=relu, init=zero, score=0.745, total=   1.5s
# [CV] activation_function=relu, init=zero .............................
# [CV] . activation_function=relu, init=zero, score=0.647, total=   1.7s
# [CV] activation_function=tanh, init=uniform ..........................
# [CV]  activation_function=tanh, init=uniform, score=0.760, total=   1.5s
# [CV] activation_function=tanh, init=uniform ..........................
# [CV]  activation_function=tanh, init=uniform, score=0.695, total=   1.5s
# [CV] activation_function=tanh, init=uniform ..........................
# [CV]  activation_function=tanh, init=uniform, score=0.747, total=   1.5s
# [CV] activation_function=tanh, init=uniform ..........................
# [CV]  activation_function=tanh, init=uniform, score=0.791, total=   1.7s
# [CV] activation_function=tanh, init=uniform ..........................
# [CV]  activation_function=tanh, init=uniform, score=0.771, total=   1.4s
# [CV] activation_function=tanh, init=normal ...........................
# [CV]  activation_function=tanh, init=normal, score=0.753, total=   1.4s
# [CV] activation_function=tanh, init=normal ...........................
# [CV]  activation_function=tanh, init=normal, score=0.721, total=   1.5s
# [CV] activation_function=tanh, init=normal ...........................
# [CV]  activation_function=tanh, init=normal, score=0.740, total=   1.7s
# [CV] activation_function=tanh, init=normal ...........................
# [CV]  activation_function=tanh, init=normal, score=0.817, total=   1.5s
# [CV] activation_function=tanh, init=normal ...........................
# [CV]  activation_function=tanh, init=normal, score=0.765, total=   1.4s
# [CV] activation_function=tanh, init=zero .............................
# [CV] . activation_function=tanh, init=zero, score=0.649, total=   1.7s
# [CV] activation_function=tanh, init=zero .............................
# [CV] . activation_function=tanh, init=zero, score=0.584, total=   1.5s
# [CV] activation_function=tanh, init=zero .............................
# [CV] . activation_function=tanh, init=zero, score=0.630, total=   1.4s
# [CV] activation_function=tanh, init=zero .............................
# [CV] . activation_function=tanh, init=zero, score=0.745, total=   1.4s
# [CV] activation_function=tanh, init=zero .............................
# [CV] . activation_function=tanh, init=zero, score=0.647, total=   1.7s
# [CV] activation_function=linear, init=uniform ........................
# [CV]  activation_function=linear, init=uniform, score=0.747, total=   1.4s
# [CV] activation_function=linear, init=uniform ........................
# [CV]  activation_function=linear, init=uniform, score=0.675, total=   1.4s
# [CV] activation_function=linear, init=uniform ........................
# [CV]  activation_function=linear, init=uniform, score=0.773, total=   1.4s
# [CV] activation_function=linear, init=uniform ........................
# [CV]  activation_function=linear, init=uniform, score=0.817, total=   1.7s
# [CV] activation_function=linear, init=uniform ........................
# [CV]  activation_function=linear, init=uniform, score=0.758, total=   1.4s
# [CV] activation_function=linear, init=normal .........................
# [CV]  activation_function=linear, init=normal, score=0.760, total=   1.4s
# [CV] activation_function=linear, init=normal .........................
# [CV]  activation_function=linear, init=normal, score=0.688, total=   1.7s
# [CV] activation_function=linear, init=normal .........................
# [CV]  activation_function=linear, init=normal, score=0.766, total=   1.4s
# [CV] activation_function=linear, init=normal .........................
# [CV]  activation_function=linear, init=normal, score=0.837, total=   1.4s
# [CV] activation_function=linear, init=normal .........................
# [CV]  activation_function=linear, init=normal, score=0.778, total=   1.4s
# [CV] activation_function=linear, init=zero ...........................
# [CV]  activation_function=linear, init=zero, score=0.649, total=   1.7s
# [CV] activation_function=linear, init=zero ...........................
# [CV]  activation_function=linear, init=zero, score=0.584, total=   1.4s
# [CV] activation_function=linear, init=zero ...........................
# [CV]  activation_function=linear, init=zero, score=0.630, total=   1.4s
# [CV] activation_function=linear, init=zero ...........................
# [CV]  activation_function=linear, init=zero, score=0.745, total=   1.7s
# [CV] activation_function=linear, init=zero ...........................
# [CV]  activation_function=linear, init=zero, score=0.647, total=   1.4s
# [Parallel(n_jobs=1)]: Done  60 out of  60 | elapsed:  1.6min finished

# %%
# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : 0.7657329559326171, using {'activation_function': 'linear', 'init': 'normal'}
# 0.5544266164302826,0.14834064402926106 with: {'activation_function': 'softmax', 'init': 'uniform'}
# 0.6511586427688598,0.05244526932680711 with: {'activation_function': 'softmax', 'init': 'normal'}
# 0.3826075911521912,0.10871273719541717 with: {'activation_function': 'softmax', 'init': 'zero'}
# 0.7240556836128235,0.05798860957418742 with: {'activation_function': 'relu', 'init': 'uniform'}
# 0.6888973712921143,0.08664873019593687 with: {'activation_function': 'relu', 'init': 'normal'}
# 0.6511586427688598,0.05244526932680711 with: {'activation_function': 'relu', 'init': 'zero'}
# 0.7526780486106872,0.03236025895642053 with: {'activation_function': 'tanh', 'init': 'uniform'}
# 0.7591970205307007,0.032375080903012075 with: {'activation_function': 'tanh', 'init': 'normal'}
# 0.6511586427688598,0.05244526932680711 with: {'activation_function': 'tanh', 'init': 'zero'}
# 0.7539937257766723,0.04599695064007678 with: {'activation_function': 'linear', 'init': 'uniform'}
# 0.7657329559326171,0.04732360433037984 with: {'activation_function': 'linear', 'init': 'normal'}
# 0.6511586427688598,0.05244526932680711 with: {'activation_function': 'linear', 'init': 'zero'}

# %% [markdown]
# #### Tuning of Hyperparameter :-Number of Neurons in activation layer

# %%
# Defining the model

def create_model(neuron1,neuron2):
    model = Sequential()
    model.add(Dense(neuron1,input_dim = 8,kernel_initializer = 'uniform',activation = 'tanh'))
    model.add(Dropout(0.1))
    model.add(Dense(neuron2,input_dim = neuron1,kernel_initializer = 'uniform',activation = 'tanh'))
    model.add(Dropout(0.1))
    model.add(Dense(1,activation = 'sigmoid'))
    
    adam = Adam(lr = 0.001)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# Create the model

model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)

# Define the grid search parameters

neuron1 = [4,8,16]
neuron2 = [2,4,8]

# Make a dictionary of the grid search parameters

param_grids = dict(neuron1 = neuron1,neuron2 = neuron2)

# Build and fit the GridSearchCV

grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] neuron1=4, neuron2=2 ............................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ................ neuron1=4, neuron2=2, score=0.753, total=   1.5s
# [CV] neuron1=4, neuron2=2 ............................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.4s remaining:    0.0s
# [CV] ................ neuron1=4, neuron2=2, score=0.675, total=   1.9s
# [CV] neuron1=4, neuron2=2 ............................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.3s remaining:    0.0s
# [CV] ................ neuron1=4, neuron2=2, score=0.708, total=   1.9s
# [CV] neuron1=4, neuron2=2 ............................................
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    5.3s remaining:    0.0s
# [CV] ................ neuron1=4, neuron2=2, score=0.817, total=   1.7s
# [CV] neuron1=4, neuron2=2 ............................................
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    6.9s remaining:    0.0s
# [CV] ................ neuron1=4, neuron2=2, score=0.765, total=   1.7s
# [CV] neuron1=4, neuron2=4 ............................................
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    8.6s remaining:    0.0s
# [CV] ................ neuron1=4, neuron2=4, score=0.766, total=   1.7s
# [CV] neuron1=4, neuron2=4 ............................................
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:   10.3s remaining:    0.0s
# [CV] ................ neuron1=4, neuron2=4, score=0.675, total=   1.5s
# [CV] neuron1=4, neuron2=4 ............................................
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:   11.8s remaining:    0.0s
# [CV] ................ neuron1=4, neuron2=4, score=0.740, total=   1.4s
# [CV] neuron1=4, neuron2=4 ............................................
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:   13.3s remaining:    0.0s
# [CV] ................ neuron1=4, neuron2=4, score=0.817, total=   1.4s
# [CV] neuron1=4, neuron2=4 ............................................
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:   14.7s remaining:    0.0s
# [CV] ................ neuron1=4, neuron2=4, score=0.758, total=   1.7s
# [CV] neuron1=4, neuron2=8 ............................................
# [CV] ................ neuron1=4, neuron2=8, score=0.747, total=   1.5s
# [CV] neuron1=4, neuron2=8 ............................................
# [CV] ................ neuron1=4, neuron2=8, score=0.688, total=   1.5s
# [CV] neuron1=4, neuron2=8 ............................................
# [CV] ................ neuron1=4, neuron2=8, score=0.753, total=   1.7s
# [CV] neuron1=4, neuron2=8 ............................................
# [CV] ................ neuron1=4, neuron2=8, score=0.824, total=   1.4s
# [CV] neuron1=4, neuron2=8 ............................................
# [CV] ................ neuron1=4, neuron2=8, score=0.765, total=   1.5s
# [CV] neuron1=8, neuron2=2 ............................................
# [CV] ................ neuron1=8, neuron2=2, score=0.753, total=   1.5s
# [CV] neuron1=8, neuron2=2 ............................................
# [CV] ................ neuron1=8, neuron2=2, score=0.675, total=   1.7s
# [CV] neuron1=8, neuron2=2 ............................................
# [CV] ................ neuron1=8, neuron2=2, score=0.747, total=   1.5s
# [CV] neuron1=8, neuron2=2 ............................................
# [CV] ................ neuron1=8, neuron2=2, score=0.817, total=   1.5s
# [CV] neuron1=8, neuron2=2 ............................................
# [CV] ................ neuron1=8, neuron2=2, score=0.758, total=   1.7s
# [CV] neuron1=8, neuron2=4 ............................................
# [CV] ................ neuron1=8, neuron2=4, score=0.760, total=   1.5s
# [CV] neuron1=8, neuron2=4 ............................................
# [CV] ................ neuron1=8, neuron2=4, score=0.701, total=   1.5s
# [CV] neuron1=8, neuron2=4 ............................................
# [CV] ................ neuron1=8, neuron2=4, score=0.753, total=   1.5s
# [CV] neuron1=8, neuron2=4 ............................................
# [CV] ................ neuron1=8, neuron2=4, score=0.817, total=   1.7s
# [CV] neuron1=8, neuron2=4 ............................................
# [CV] ................ neuron1=8, neuron2=4, score=0.758, total=   1.5s
# [CV] neuron1=8, neuron2=8 ............................................
# [CV] ................ neuron1=8, neuron2=8, score=0.766, total=   1.5s
# [CV] neuron1=8, neuron2=8 ............................................
# [CV] ................ neuron1=8, neuron2=8, score=0.708, total=   1.5s
# [CV] neuron1=8, neuron2=8 ............................................
# [CV] ................ neuron1=8, neuron2=8, score=0.753, total=   1.7s
# [CV] neuron1=8, neuron2=8 ............................................
# [CV] ................ neuron1=8, neuron2=8, score=0.837, total=   1.4s
# [CV] neuron1=8, neuron2=8 ............................................
# [CV] ................ neuron1=8, neuron2=8, score=0.765, total=   1.5s
# [CV] neuron1=16, neuron2=2 ...........................................
# [CV] ............... neuron1=16, neuron2=2, score=0.766, total=   1.7s
# [CV] neuron1=16, neuron2=2 ...........................................
# [CV] ............... neuron1=16, neuron2=2, score=0.708, total=   1.5s
# [CV] neuron1=16, neuron2=2 ...........................................
# [CV] ............... neuron1=16, neuron2=2, score=0.760, total=   1.4s
# [CV] neuron1=16, neuron2=2 ...........................................
# [CV] ............... neuron1=16, neuron2=2, score=0.830, total=   1.4s
# [CV] neuron1=16, neuron2=2 ...........................................
# [CV] ............... neuron1=16, neuron2=2, score=0.778, total=   1.7s
# [CV] neuron1=16, neuron2=4 ...........................................
# [CV] ............... neuron1=16, neuron2=4, score=0.753, total=   1.5s
# [CV] neuron1=16, neuron2=4 ...........................................
# [CV] ............... neuron1=16, neuron2=4, score=0.721, total=   1.5s
# [CV] neuron1=16, neuron2=4 ...........................................
# [CV] ............... neuron1=16, neuron2=4, score=0.760, total=   1.7s
# [CV] neuron1=16, neuron2=4 ...........................................
# [CV] ............... neuron1=16, neuron2=4, score=0.837, total=   1.5s
# [CV] neuron1=16, neuron2=4 ...........................................
# [CV] ............... neuron1=16, neuron2=4, score=0.745, total=   1.5s
# [CV] neuron1=16, neuron2=8 ...........................................
# [CV] ............... neuron1=16, neuron2=8, score=0.773, total=   1.5s
# [CV] neuron1=16, neuron2=8 ...........................................
# [CV] ............... neuron1=16, neuron2=8, score=0.721, total=   1.8s
# [CV] neuron1=16, neuron2=8 ...........................................
# [CV] ............... neuron1=16, neuron2=8, score=0.760, total=   1.5s
# [CV] neuron1=16, neuron2=8 ...........................................
# [CV] ............... neuron1=16, neuron2=8, score=0.810, total=   1.6s
# [CV] neuron1=16, neuron2=8 ...........................................
# [CV] ............... neuron1=16, neuron2=8, score=0.758, total=   1.4s
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed:  1.2min finished

# %%
# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : 0.7683218717575073, using {'neuron1': 16, 'neuron2': 2}
# 0.7436125993728637,0.04872132181450058 with: {'neuron1': 4, 'neuron2': 2}
# 0.7513963222503662,0.04578195138420501 with: {'neuron1': 4, 'neuron2': 4}
# 0.7553094029426575,0.043147235871533594 with: {'neuron1': 4, 'neuron2': 8}
# 0.7500976204872132,0.04506065290310772 with: {'neuron1': 8, 'neuron2': 2}
# 0.7578898191452026,0.036662940909555845 with: {'neuron1': 8, 'neuron2': 4}
# 0.7657159805297852,0.041319882263155645 with: {'neuron1': 8, 'neuron2': 8}
# 0.7683218717575073,0.03909863725607777 with: {'neuron1': 16, 'neuron2': 2}
# 0.763093113899231,0.039053643060705794 with: {'neuron1': 16, 'neuron2': 4}
# 0.764374840259552,0.028823370545363006 with: {'neuron1': 16, 'neuron2': 8}

# %% [markdown]
# #### Training model with optimum values of Hyperparameters

# %%
from sklearn.metrics import classification_report, accuracy_score

# Defining the model

def create_model():
    model = Sequential()
    model.add(Dense(16,input_dim = 8,kernel_initializer = 'uniform',activation = 'tanh'))
    model.add(Dropout(0.1))
    model.add(Dense(4,input_dim = 16,kernel_initializer = 'uniform',activation = 'tanh'))
    model.add(Dropout(0.1))
    model.add(Dense(1,activation = 'sigmoid'))
    
    adam = Adam(lr = 0.001) #sgd = SGD(lr=learning_rate, momentum=momentum, decay=decay_rate, nesterov=False)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# Create the model

model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)

# Fitting the model

model.fit(X_standardized,y)

# Predicting using trained model

y_predict = model.predict(X_standardized)

# Printing the metrics
print(accuracy_score(y,y_predict))
# Out:
# C:\Users\Kavya Ramesh\anaconda3\lib\site-packages\tensorflow\python\keras\engine\sequential.py:455: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# 0.7734375

# %% [markdown]
# # Hyperparameters all at once

# %% [markdown]
# The hyperparameter optimization was carried out by taking 2 hyperparameters at once. We may have missed the best values. The performance can be further improved by finding the optimum values of hyperparameters all at once given by the code snippet below.
# #### This process is computationally expensive.

# %%
def create_model(learning_rate,dropout_rate,activation_function,init,neuron1,neuron2):
    model = Sequential()
    model.add(Dense(neuron1,input_dim = 8,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(dropout_rate))
    model.add(Dense(neuron2,input_dim = neuron1,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(dropout_rate))
    model.add(Dense(1,activation = 'sigmoid'))
    
    adam = Adam(lr = learning_rate)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# Create the model

model = KerasClassifier(build_fn = create_model,verbose = 0)

# Define the grid search parameters

batch_size = [10,20,40]
epochs = [10,50,100]
learning_rate = [0.001,0.01,0.1]
dropout_rate = [0.0,0.1,0.2]
activation_function = ['softmax','relu','tanh','linear']
init = ['uniform','normal','zero']
neuron1 = [4,8,16]
neuron2 = [2,4,8]

# Make a dictionary of the grid search parameters

param_grids = dict(batch_size = batch_size,epochs = epochs,learning_rate = learning_rate,dropout_rate = dropout_rate,
                   activation_function = activation_function,init = init,neuron1 = neuron1,neuron2 = neuron2)

# Build and fit the GridSearchCV

grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)

# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Fitting 5 folds for each of 8748 candidates, totalling 43740 fits
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2, score=0.649, total=   2.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.7s remaining:    0.0s
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2, score=0.584, total=   2.8s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    5.5s remaining:    0.0s
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2, score=0.630, total=   2.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    7.6s remaining:    0.0s
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2, score=0.745, total=   2.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    9.7s remaining:    0.0s
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2, score=0.647, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   11.7s remaining:    0.0s
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4, score=0.649, total=   2.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:   13.8s remaining:    0.0s
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4, score=0.584, total=   2.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:   16.1s remaining:    0.0s
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4, score=0.630, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:   18.2s remaining:    0.0s
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4, score=0.745, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:   20.2s remaining:    0.0s
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=4, score=0.647, total=   2.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8, score=0.649, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8, score=0.584, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8, score=0.630, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8, score=0.745, total=   2.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=4, neuron2=8, score=0.647, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=2, score=0.649, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=2, score=0.584, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=2, score=0.630, total=   2.4s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=2, score=0.745, total=   2.4s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=2, score=0.647, total=   2.4s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=4, score=0.649, total=   2.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=4, score=0.584, total=   2.4s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=4, score=0.630, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=4, score=0.745, total=   2.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=4, score=0.647, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=8, score=0.649, total=   2.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=8, score=0.584, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=8, score=0.630, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=8, score=0.745, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=8, neuron2=8, score=0.647, total=   2.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=2, score=0.649, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=2, score=0.584, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=2, score=0.370, total=   2.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=2, score=0.745, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=2, score=0.647, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=4, score=0.649, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=4, score=0.584, total=   2.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=4, score=0.630, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=4, score=0.745, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=4, score=0.647, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=8, score=0.649, total=   2.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=8, score=0.584, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=8, score=0.630, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=8, score=0.745, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.001, neuron1=16, neuron2=8, score=0.647, total=   2.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2, score=0.727, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2, score=0.708, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2, score=0.760, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2, score=0.824, total=   2.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=2, score=0.752, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4, score=0.753, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4, score=0.708, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4, score=0.760, total=   2.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4, score=0.843, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=4, score=0.758, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8, score=0.727, total=   2.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8, score=0.727, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8, score=0.760, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8, score=0.863, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=4, neuron2=8, score=0.765, total=   2.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2, score=0.727, total=   2.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2, score=0.701, total=   2.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2, score=0.760, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2, score=0.830, total=   2.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=2, score=0.765, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4, score=0.727, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4, score=0.740, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4, score=0.766, total=   2.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4, score=0.837, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=4, score=0.758, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=8, score=0.740, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=8, score=0.727, total=   2.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=8, score=0.766, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=8, score=0.824, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=8, neuron2=8, score=0.752, total=   2.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2, score=0.727, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2, score=0.688, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2, score=0.753, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2, score=0.804, total=   2.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=2, score=0.758, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4, score=0.734, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4, score=0.682, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4, score=0.760, total=   2.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4, score=0.817, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=4, score=0.758, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8, score=0.721, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8, score=0.708, total=   2.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8, score=0.753, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8, score=0.830, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.01, neuron1=16, neuron2=8, score=0.765, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2, score=0.721, total=   2.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2, score=0.675, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2, score=0.727, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2, score=0.830, total=   2.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=2, score=0.752, total=   2.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4, score=0.695, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4, score=0.747, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4, score=0.753, total=   2.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4, score=0.765, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=4, score=0.758, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=8, score=0.721, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=8, score=0.714, total=   2.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=8, score=0.753, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=8, score=0.850, total=   2.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=4, neuron2=8, score=0.752, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2, score=0.682, total=   2.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2, score=0.662, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2, score=0.766, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2, score=0.752, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=2, score=0.758, total=   2.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4, score=0.714, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4, score=0.721, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4, score=0.747, total=   2.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4, score=0.817, total=   2.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=4, score=0.732, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=8, score=0.708, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=8, score=0.662, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=8, score=0.773, total=   2.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=8, score=0.784, total=   2.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=8, neuron2=8, score=0.706, total=   2.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=2, score=0.695, total=   2.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=2, score=0.682, total=   2.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=2, score=0.773, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=2, score=0.725, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=2, score=0.732, total=   2.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=4, score=0.682, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=4, score=0.649, total=   2.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=4, score=0.773, total=   2.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=4, score=0.745, total=   2.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=4, score=0.758, total=   2.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=8, score=0.721, total=   2.4s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=8, score=0.662, total=   2.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=8, score=0.747, total=   2.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=8, score=0.830, total=   2.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=uniform, learning_rate=0.1, neuron1=16, neuron2=8, score=0.758, total=   2.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=2, score=0.649, total=   2.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=2, score=0.584, total=   2.4s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=2, score=0.760, total=   2.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=2, score=0.745, total=   2.4s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=2, score=0.647, total=   2.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=4, score=0.649, total=   2.7s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=4, score=0.584, total=   2.4s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=4, score=0.630, total=   2.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=4, score=0.745, total=   2.4s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=4, score=0.647, total=   2.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=8, score=0.649, total=   2.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=8, score=0.584, total=   2.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=8, score=0.630, total=   2.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=8, score=0.745, total=   2.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=4, neuron2=8, score=0.647, total=   2.4s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=8, neuron2=2, score=0.649, total=   2.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=8, neuron2=2, score=0.584, total=   2.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=8, neuron2=2, score=0.630, total=   2.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=8, neuron2=2, score=0.745, total=   2.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=8, neuron2=2, score=0.647, total=   2.4s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=8, neuron2=4, score=0.649, total=   2.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=8, neuron2=4, score=0.584, total=   2.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=8, neuron2=4, score=0.630, total=   2.4s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.0, epochs=10, init=normal, learning_rate=0.001, neuron1=8, neuron2=4
# ...
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.01, neuron1=16, neuron2=4, score=0.675, total=   1.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.01, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.01, neuron1=16, neuron2=4, score=0.766, total=   1.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.01, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.01, neuron1=16, neuron2=4, score=0.843, total=   1.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.01, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.01, neuron1=16, neuron2=4, score=0.758, total=   1.4s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.01, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.01, neuron1=16, neuron2=8, score=0.721, total=   1.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.01, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.01, neuron1=16, neuron2=8, score=0.701, total=   1.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.01, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.01, neuron1=16, neuron2=8, score=0.753, total=   1.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.01, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.01, neuron1=16, neuron2=8, score=0.817, total=   1.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.01, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.01, neuron1=16, neuron2=8, score=0.771, total=   1.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=4, neuron2=2, score=0.688, total=   1.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=4, neuron2=2, score=0.727, total=   1.6s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=4, neuron2=2, score=0.753, total=   1.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=4, neuron2=2, score=0.791, total=   1.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=4, neuron2=2, score=0.765, total=   1.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=4, neuron2=4, score=0.727, total=   1.4s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=4, neuron2=4, score=0.701, total=   1.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=4, neuron2=4, score=0.753, total=   1.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=4, neuron2=4, score=0.778, total=   1.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=4, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=4, neuron2=4, score=0.758, total=   1.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=4, neuron2=8, score=0.721, total=   1.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=4, neuron2=8, score=0.708, total=   1.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=4, neuron2=8, score=0.630, total=   1.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=4, neuron2=8, score=0.830, total=   1.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=4, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=4, neuron2=8, score=0.732, total=   1.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=8, neuron2=2, score=0.734, total=   1.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=8, neuron2=2, score=0.649, total=   1.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=8, neuron2=2, score=0.760, total=   1.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=8, neuron2=2, score=0.745, total=   1.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=8, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=8, neuron2=2, score=0.739, total=   0.9s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=8, neuron2=4, score=0.740, total=   1.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=8, neuron2=4, score=0.682, total=   1.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=8, neuron2=4, score=0.766, total=   1.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=8, neuron2=4, score=0.843, total=   1.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=8, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=8, neuron2=4, score=0.752, total=   1.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=8, neuron2=8, score=0.747, total=   1.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=8, neuron2=8, score=0.695, total=   1.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=8, neuron2=8, score=0.747, total=   1.4s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=8, neuron2=8, score=0.830, total=   1.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=8, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=8, neuron2=8, score=0.752, total=   1.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=16, neuron2=2, score=0.695, total=   1.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=16, neuron2=2, score=0.721, total=   1.4s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=16, neuron2=2, score=0.747, total=   1.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=16, neuron2=2, score=0.680, total=   1.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=16, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=16, neuron2=2, score=0.680, total=   1.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=16, neuron2=4, score=0.714, total=   1.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=16, neuron2=4, score=0.688, total=   1.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=16, neuron2=4, score=0.773, total=   1.5s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=16, neuron2=4, score=0.797, total=   1.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=16, neuron2=4
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=16, neuron2=4, score=0.693, total=   1.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=16, neuron2=8, score=0.760, total=   1.1s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=16, neuron2=8, score=0.643, total=   1.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=16, neuron2=8, score=0.747, total=   1.3s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=16, neuron2=8, score=0.784, total=   1.2s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=16, neuron2=8
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=10, init=zero, learning_rate=0.1, neuron1=16, neuron2=8, score=0.706, total=   1.0s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2
# [CV]  activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2, score=0.747, total=   2.7s
# [CV] activation_function=softmax, batch_size=10, dropout_rate=0.1, epochs=50, init=uniform, learning_rate=0.001, neuron1=4, neuron2=2
