# %%
import pandas as pd  
import numpy as np
from sklearn import preprocessing

# %%
sdtrain = pd.read_csv('C:\\Data Science\\KNN and SVM\\SalaryData_Train(1).csv')
sdtrain
# Out:
#        age          workclass    education  educationno        maritalstatus  \
# 0       39          State-gov    Bachelors           13        Never-married
# 1       50   Self-emp-not-inc    Bachelors           13   Married-civ-spouse
# 2       38            Private      HS-grad            9             Divorced
# 3       53            Private         11th            7   Married-civ-spouse
# 4       28            Private    Bachelors           13   Married-civ-spouse
# ...    ...                ...          ...          ...                  ...
# 30156   27            Private   Assoc-acdm           12   Married-civ-spouse
# 30157   40            Private      HS-grad            9   Married-civ-spouse
# 30158   58            Private      HS-grad            9              Widowed
# 30159   22            Private      HS-grad            9        Never-married
# 30160   52       Self-emp-inc      HS-grad            9   Married-civ-spouse
#
# ...

# %%
sd =sdtrain.drop(['educationno','age','native'],axis=1)
sd
# Out:
#                workclass    education        maritalstatus  \
# 0              State-gov    Bachelors        Never-married
# 1       Self-emp-not-inc    Bachelors   Married-civ-spouse
# 2                Private      HS-grad             Divorced
# 3                Private         11th   Married-civ-spouse
# 4                Private    Bachelors   Married-civ-spouse
# ...                  ...          ...                  ...
# 30156            Private   Assoc-acdm   Married-civ-spouse
# 30157            Private      HS-grad   Married-civ-spouse
# 30158            Private      HS-grad              Widowed
# 30159            Private      HS-grad        Never-married
# 30160       Self-emp-inc      HS-grad   Married-civ-spouse
#
#                occupation    relationship    race      sex  capitalgain  \
# 0            Adm-clerical   Not-in-family   White     Male         2174
# 1         Exec-managerial         Husband   White     Male            0
# ...

# %%
sdtrain.relationship.value_counts()
# Out:
#  Husband           12463
#  Not-in-family      7726
#  Own-child          4466
#  Unmarried          3212
#  Wife               1406
#  Other-relative      888
# Name: relationship, dtype: int64

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
sd['Salary'] = label_encoder.fit_transform(sd['Salary']) 
sd['education'] = label_encoder.fit_transform(sd['education']) 
sd['occupation'] = label_encoder.fit_transform(sd['occupation']) 
sd['sex'] = label_encoder.fit_transform(sd['sex'])
sd['maritalstatus'] = label_encoder.fit_transform(sd['maritalstatus'])
sd['race'] = label_encoder.fit_transform(sd['race'])
sd['workclass'] = label_encoder.fit_transform(sd['workclass'])
sd['relationship'] = label_encoder.fit_transform(sd['relationship'])

# %%
sd
# Out:
#        workclass  education  maritalstatus  occupation  relationship  race  \
# 0              5          9              4           0             1     4
# 1              4          9              2           3             0     4
# 2              2         11              0           5             1     4
# 3              2          1              2           5             0     2
# 4              2          9              2           9             5     2
# ...          ...        ...            ...         ...           ...   ...
# 30156          2          7              2          12             5     4
# 30157          2         11              2           6             0     4
# 30158          2         11              6           0             4     4
# 30159          2         11              4           0             3     4
# 30160          3         11              2           3             5     4
#
#        sex  capitalgain  capitalloss  hoursperweek  Salary
# ...

# %%
sd1 =sd.drop_duplicates() 
sd1
# Out:
#        workclass  education  maritalstatus  occupation  relationship  race  \
# 0              5          9              4           0             1     4
# 1              4          9              2           3             0     4
# 2              2         11              0           5             1     4
# 3              2          1              2           5             0     2
# 4              2          9              2           9             5     2
# ...          ...        ...            ...         ...           ...   ...
# 30149          5         15              0           0             2     4
# 30151          2          0              2           5             0     0
# 30153          2         12              4          12             1     1
# 30156          2          7              2          12             5     4
# 30160          3         11              2           3             5     4
#
#        sex  capitalgain  capitalloss  hoursperweek  Salary
# ...

# %%
X = sd1.iloc[:,0:10]
X
# Out:
#        workclass  education  maritalstatus  occupation  relationship  race  \
# 0              5          9              4           0             1     4
# 1              4          9              2           3             0     4
# 2              2         11              0           5             1     4
# 3              2          1              2           5             0     2
# 4              2          9              2           9             5     2
# ...          ...        ...            ...         ...           ...   ...
# 30149          5         15              0           0             2     4
# 30151          2          0              2           5             0     0
# 30153          2         12              4          12             1     1
# 30156          2          7              2          12             5     4
# 30160          3         11              2           3             5     4
#
#        sex  capitalgain  capitalloss  hoursperweek
# ...

# %%
y= sd1.iloc[:,10]
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 30149    0
# 30151    0
# 30153    0
# 30156    0
# 30160    1
# Name: Salary, Length: 16863, dtype: int32

# %%
#test train data
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import accuracy_score ,confusion_matrix
 
X1_train , X1_test, y1_train, y1_test = train_test_split(X, y ,test_size = 0.2, random_state= 0,shuffle=True)

# %%
X1_train.shape, y1_train.shape, X1_test.shape, y1_test.shape
# Out:
# ((13490, 10), (13490,), (3373, 10), (3373,))

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer 

from sklearn import svm
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report

# %%
clf = SVC()
param_grid = [{'kernel':['rbf'],'gamma':[0.1,0.2],'C':[1,10]}]
gsv = GridSearchCV(clf,param_grid,cv=10)
gsv.fit(X,y)
# Out:
# GridSearchCV(cv=10, estimator=SVC(),
#              param_grid=[{'C': [1, 10], 'gamma': [0.1, 0.2],
#                           'kernel': ['rbf']}])

# %%
gsv.best_params_ , gsv.best_score_
# Out:
# ({'C': 1, 'gamma': 0.1, 'kernel': 'rbf'}, 0.8177676475117446)

# %%
stest = pd.read_csv('C:\\Data Science\\KNN and SVM\\SalaryData_Test(1).csv')
stest
# Out:
#        age      workclass      education  educationno        maritalstatus  \
# 0       25        Private           11th            7        Never-married
# 1       38        Private        HS-grad            9   Married-civ-spouse
# 2       28      Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3       44        Private   Some-college           10   Married-civ-spouse
# 4       34        Private           10th            6        Never-married
# ...    ...            ...            ...          ...                  ...
# 15055   33        Private      Bachelors           13        Never-married
# 15056   39        Private      Bachelors           13             Divorced
# 15057   38        Private      Bachelors           13   Married-civ-spouse
# 15058   44        Private      Bachelors           13             Divorced
# 15059   35   Self-emp-inc      Bachelors           13   Married-civ-spouse
#
# ...

# %%
st =stest.drop(['educationno','age','native'],axis=1)
st
# Out:
#            workclass      education        maritalstatus          occupation  \
# 0            Private           11th        Never-married   Machine-op-inspct
# 1            Private        HS-grad   Married-civ-spouse     Farming-fishing
# 2          Local-gov     Assoc-acdm   Married-civ-spouse     Protective-serv
# 3            Private   Some-college   Married-civ-spouse   Machine-op-inspct
# 4            Private           10th        Never-married       Other-service
# ...              ...            ...                  ...                 ...
# 15055        Private      Bachelors        Never-married      Prof-specialty
# 15056        Private      Bachelors             Divorced      Prof-specialty
# 15057        Private      Bachelors   Married-civ-spouse      Prof-specialty
# 15058        Private      Bachelors             Divorced        Adm-clerical
# 15059   Self-emp-inc      Bachelors   Married-civ-spouse     Exec-managerial
#
# ...

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
st['Salary'] = label_encoder.fit_transform(st['Salary']) 
st['education'] = label_encoder.fit_transform(st['education']) 
st['occupation'] = label_encoder.fit_transform(st['occupation']) 
st['sex'] = label_encoder.fit_transform(st['sex'])
st['maritalstatus'] = label_encoder.fit_transform(st['maritalstatus'])
st['race'] = label_encoder.fit_transform(st['race'])
st['workclass'] = label_encoder.fit_transform(st['workclass'])
st['relationship'] = label_encoder.fit_transform(st['relationship'])

# %%
st
# Out:
#        workclass  education  maritalstatus  occupation  relationship  race  \
# 0              2          1              4           6             3     2
# 1              2         11              2           4             0     4
# 2              1          7              2          10             0     4
# 3              2         15              2           6             0     2
# 4              2          0              4           7             1     4
# ...          ...        ...            ...         ...           ...   ...
# 15055          2          9              4           9             3     4
# 15056          2          9              0           9             1     4
# 15057          2          9              2           9             0     4
# 15058          2          9              0           0             3     1
# 15059          3          9              2           3             0     4
#
#        sex  capitalgain  capitalloss  hoursperweek  Salary
# ...

# %%
st1 =st.drop_duplicates() 
st1
# Out:
#        workclass  education  maritalstatus  occupation  relationship  race  \
# 0              2          1              4           6             3     2
# 1              2         11              2           4             0     4
# 2              1          7              2          10             0     4
# 3              2         15              2           6             0     2
# 4              2          0              4           7             1     4
# ...          ...        ...            ...         ...           ...   ...
# 15046          2         11              5           8             1     4
# 15047          2          8              4           0             4     2
# 15048          2          7              0           9             1     4
# 15054          1         12              0           7             1     4
# 15058          2          9              0           0             3     1
#
#        sex  capitalgain  capitalloss  hoursperweek  Salary
# ...

# %%
x_test = st1.iloc[:,0:10]
x_test
# Out:
#        workclass  education  maritalstatus  occupation  relationship  race  \
# 0              2          1              4           6             3     2
# 1              2         11              2           4             0     4
# 2              1          7              2          10             0     4
# 3              2         15              2           6             0     2
# 4              2          0              4           7             1     4
# ...          ...        ...            ...         ...           ...   ...
# 15046          2         11              5           8             1     4
# 15047          2          8              4           0             4     2
# 15048          2          7              0           9             1     4
# 15054          1         12              0           7             1     4
# 15058          2          9              0           0             3     1
#
#        sex  capitalgain  capitalloss  hoursperweek
# ...

# %%
y_test = st1['Salary']
y_test
# Out:
# 0        0
# 1        0
# 2        1
# 3        1
# 4        0
#         ..
# 15046    0
# 15047    0
# 15048    0
# 15054    0
# 15058    0
# Name: Salary, Length: 9684, dtype: int64

# %%
clf = SVC(C= 1, gamma = 0.1, kernel = 'rbf')
clf.fit(X,y)
y_pred = clf.predict(x_test)
acc = accuracy_score(y_test, y_pred) * 100
print("Accuracy =", acc)
confusion_matrix(y_test, y_pred)
# Out:
# Accuracy = 83.5811648079306
# array([[7011,  271],
#        [1319, 1083]], dtype=int64)
